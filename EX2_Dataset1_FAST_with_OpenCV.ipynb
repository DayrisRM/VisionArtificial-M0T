# %% [markdown]
# <a href="https://colab.research.google.com/github/DayrisRM/VisionArtificial-M0T/blob/master/EX2_Dataset1_FAST_with_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Load the image
image1 = cv2.imread('t7.png')

# %%
# Create detector
fast = cv2.FastFeatureDetector_create()

# %%
# Detect keypoints with non max suppression
keypoints_with_nonmax = fast.detect(image1, None)

# %%
# Disable nonmaxSuppression 
fast.setNonmaxSuppression(False)

# %%
# Detect keypoints without non max suppression
keypoints_without_nonmax = fast.detect(image1, None)

# %%
image_with_nonmax = np.copy(image1)
image_without_nonmax = np.copy(image1)

# %%
cv2.drawKeypoints(image1, keypoints_with_nonmax, image_with_nonmax, color=(0,255,0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv2.drawKeypoints(image1, keypoints_without_nonmax, image_without_nonmax, color=(0,255,0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# Display image with and without non max suppression
fx, plots = plt.subplots(1, 2, figsize=(20,10))

plots[0].set_title("With non max suppression")
plots[0].imshow(image_with_nonmax)

plots[1].set_title("Without non max suppression")
plots[1].imshow(image_without_nonmax)

# %%
# Print the number of keypoints detected in the training image
print("Number of Keypoints Detected In The Image With Non Max Suppression: ", len(keypoints_with_nonmax))

# Print the number of keypoints detected in the query image
print("Number of Keypoints Detected In The Image Without Non Max Suppression: ", len(keypoints_without_nonmax))
# Out:
# Number of Keypoints Detected In The Image With Non Max Suppression:  487
# Number of Keypoints Detected In The Image Without Non Max Suppression:  2636

# %%
imgDraw=cv2.drawKeypoints(image1,keypoints_with_nonmax,None,(255,0,0),4)
cv2.imwrite('fast_t7_keypoints.png',imgDraw)
# Out:
# True
